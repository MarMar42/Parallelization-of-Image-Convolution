# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid",palette="deep")

# %%
lena_df = pd.read_csv("Lena512.csv", sep = ';')

# %% [markdown]
# # Lena 512

# %%
n = [9,25,49]

i = 8
L_CPU = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& (lena_df['Type'] == 'CPU')]["Run Time"].to_numpy()
L_naive = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& (lena_df['Type'] == 'GPU(Global)')]["Run Time"].to_numpy()
L_gConst = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& (lena_df['Type'] == 'GPU(Global Constant)')]["Run Time"].to_numpy()
L_share = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& ((lena_df['Type'] == 'GPU(Share) Tile Size = 10') | (lena_df['Type'] == 'GPU(Share) Tile Size = 12') | (lena_df['Type'] == 'GPU(Share) Tile Size = 14'))]["Run Time"].to_numpy()
L_sConst = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& ((lena_df['Type'] == 'GPU(Shared Constant) Tile Size = 10') | (lena_df['Type'] == 'GPU(Shared Constant) Tile Size = 12') | (lena_df['Type'] == 'GPU(Shared Constant) Tile Size = 14'))]["Run Time"].to_numpy()
L_tex = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& (lena_df['Type'] == 'GPU(Texture)')]["Run Time"].to_numpy()
L_sConst

fig, (ax1,ax2,ax3) = plt.subplots(nrows = 1, ncols = 3,sharey='row',sharex = "all", squeeze=True, figsize= (20,5))
fig.suptitle("Run Times of Various Sized Filters Applied to a 512x512 Image",fontsize = 14)
#8
ax1.semilogy(n,L_CPU, label = "CPU")
ax1.semilogy(n,L_naive, label = 'Naive')
ax1.semilogy(n,L_gConst, label = "Global Constant")
ax1.semilogy(n,L_share, label = 'Shared')
ax1.semilogy(n,L_sConst, label = 'Shared Constant')
ax1.semilogy(n,L_tex, label = 'Texture')
ax1.set_title("Threads = "+str(i),fontsize = 13)
ax1.set_xlabel("Dimension of the Filter (NxN)",fontsize = 13)
ax1.set_ylabel("Run Time (ms)",fontsize = 13)
ax1.legend(fontsize = 10, loc = 'best')


i = 16
L_CPU = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& (lena_df['Type'] == 'CPU')]["Run Time"].to_numpy()
L_naive = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& (lena_df['Type'] == 'GPU(Global)')]["Run Time"].to_numpy()
L_gConst = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& (lena_df['Type'] == 'GPU(Global Constant)')]["Run Time"].to_numpy()
L_share = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& ((lena_df['Type'] == 'GPU(Share) Tile Size = 18') | (lena_df['Type'] == 'GPU(Share) Tile Size = 20') | (lena_df['Type'] == 'GPU(Share) Tile Size = 22'))]["Run Time"].to_numpy()
L_sConst = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& ((lena_df['Type'] == 'GPU(Shared Constant) Tile Size = 18') | (lena_df['Type'] == 'GPU(Shared Constant) Tile Size = 20') | (lena_df['Type'] == 'GPU(Shared Constant) Tile Size = 22'))]["Run Time"].to_numpy()
L_tex = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& (lena_df['Type'] == 'GPU(Texture)')]["Run Time"].to_numpy()



#16
ax2.semilogy(n,L_CPU, label = "CPU")
ax2.semilogy(n,L_naive, label = 'Naive')
ax2.semilogy(n,L_gConst, label = "Global Constant")
ax2.semilogy(n,L_share, label = 'Shared')
ax2.semilogy(n,L_sConst, label = 'Shared Constant')
ax2.semilogy(n,L_tex, label = 'Texture')
ax2.set_title("Threads = "+str(i),fontsize = 13)
ax2.set_xlabel("Dimension of the Filter (NxN)",fontsize = 13)

ax2.legend(fontsize = 10, loc = 'best')


i = 32
L_CPU = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& (lena_df['Type'] == 'CPU')]["Run Time"].to_numpy()
L_naive = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& (lena_df['Type'] == 'GPU(Global)')]["Run Time"].to_numpy()
L_gConst = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& (lena_df['Type'] == 'GPU(Global Constant)')]["Run Time"].to_numpy()
L_share = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& ((lena_df['Type'] == 'GPU(Share) Tile Size = 34') | (lena_df['Type'] == 'GPU(Share) Tile Size = 36') | (lena_df['Type'] == 'GPU(Share) Tile Size = 38'))]["Run Time"].to_numpy()
L_sConst = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& ((lena_df['Type'] == 'GPU(Shared Constant) Tile Size = 34') | (lena_df['Type'] == 'GPU(Shared Constant) Tile Size = 36') | (lena_df['Type'] == 'GPU(Shared Constant) Tile Size = 38'))]["Run Time"].to_numpy()
L_tex = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& (lena_df['Type'] == 'GPU(Texture)')]["Run Time"].to_numpy()



#32
ax3.semilogy(n,L_CPU, label = "CPU")
ax3.semilogy(n,L_naive, label = 'Naive')
ax3.semilogy(n,L_gConst, label = "Global Constant")
ax3.semilogy(n,L_share, label = 'Shared')
ax3.semilogy(n,L_sConst, label = 'Shared Constant')
ax3.semilogy(n,L_tex, label = 'Texture')
ax3.set_title("Threads = "+str(i),fontsize = 13)
ax3.set_xlabel("Dimension of the Filter (NxN)",fontsize = 13)
ax3.legend(fontsize = 10, loc = 'best')
plt.subplots_adjust(wspace = 0.01,hspace = 0)
plt.show()

fig.savefig('Lena Graph.png')

# %% [markdown]
# # Harvard1080

# %%
lena_df = pd.read_csv("Harvard1080.csv", sep = ';')

i = 8
L_CPU = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& (lena_df['Type'] == 'CPU')]["Run Time"].to_numpy()
L_naive = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& (lena_df['Type'] == 'GPU(Global)')]["Run Time"].to_numpy()
L_gConst = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& (lena_df['Type'] == 'GPU(Global Constant)')]["Run Time"].to_numpy()
L_share = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& ((lena_df['Type'] == 'GPU(Share) Tile Size = 10') | (lena_df['Type'] == 'GPU(Share) Tile Size = 12') | (lena_df['Type'] == 'GPU(Share) Tile Size = 14'))]["Run Time"].to_numpy()
L_sConst = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& ((lena_df['Type'] == 'GPU(Shared Constant) Tile Size = 10') | (lena_df['Type'] == 'GPU(Shared Constant) Tile Size = 12') | (lena_df['Type'] == 'GPU(Shared Constant) Tile Size = 14'))]["Run Time"].to_numpy()
L_tex = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& (lena_df['Type'] == 'GPU(Texture)')]["Run Time"].to_numpy()


n = [9,25,49]
fig1, (ax4,ax5,ax6) = plt.subplots(nrows = 1, ncols = 3,sharey='row', squeeze=True, figsize= (20,5))
fig1.suptitle("Run Times of Various Sized Filters Applied to a 1080x1080 Image",fontsize = 14)

#8
ax4.semilogy(n,L_CPU, label = "CPU")
ax4.semilogy(n,L_naive, label = 'Naive')
ax4.semilogy(n,L_gConst, label = "Global Constant")
ax4.semilogy(n,L_share, label = 'Shared')
ax4.semilogy(n,L_sConst, label = 'Shared Constant')
ax4.semilogy(n,L_tex, label = 'Texture')
ax4.set_title("Threads = "+str(i),fontsize = 13)
ax4.set_xlabel("Dimensions of Filter (NxN)",fontsize = 13)
ax4.set_ylabel("Run Time (ms)",fontsize = 13)

ax4.legend(fontsize = 10, loc = 'best')


i = 16
L_CPU = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& (lena_df['Type'] == 'CPU')]["Run Time"].to_numpy()
L_naive = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& (lena_df['Type'] == 'GPU(Global)')]["Run Time"].to_numpy()
L_gConst = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& (lena_df['Type'] == 'GPU(Global Constant)')]["Run Time"].to_numpy()
L_share = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& ((lena_df['Type'] == 'GPU(Share) Tile Size = 18') | (lena_df['Type'] == 'GPU(Share) Tile Size = 20') | (lena_df['Type'] == 'GPU(Share) Tile Size = 22'))]["Run Time"].to_numpy()
L_sConst = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& ((lena_df['Type'] == 'GPU(Shared Constant) Tile Size = 18') | (lena_df['Type'] == 'GPU(Shared Constant) Tile Size = 20') | (lena_df['Type'] == 'GPU(Shared Constant) Tile Size = 22'))]["Run Time"].to_numpy()
L_tex = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& (lena_df['Type'] == 'GPU(Texture)')]["Run Time"].to_numpy()


#16
ax5.semilogy(n,L_CPU, label = "CPU")
ax5.semilogy(n,L_naive, label = 'Naive')
ax5.semilogy(n,L_gConst, label = "Global Constant")
ax5.semilogy(n,L_share, label = 'Shared')
ax5.semilogy(n,L_sConst, label = 'Shared Constant')
ax5.semilogy(n,L_tex, label = 'Texture')
ax5.set_title("Threads = "+str(i),fontsize = 13)
ax5.set_xlabel("Dimensions of Filter (NxN)",fontsize = 13)

ax5.legend(fontsize = 10, loc = 'best')


i = 32
L_CPU = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& (lena_df['Type'] == 'CPU')]["Run Time"].to_numpy()
L_naive = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& (lena_df['Type'] == 'GPU(Global)')]["Run Time"].to_numpy()
L_gConst = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& (lena_df['Type'] == 'GPU(Global Constant)')]["Run Time"].to_numpy()
L_share = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& ((lena_df['Type'] == 'GPU(Share) Tile Size = 34') | (lena_df['Type'] == 'GPU(Share) Tile Size = 36') | (lena_df['Type'] == 'GPU(Share) Tile Size = 38'))]["Run Time"].to_numpy()
L_sConst = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& ((lena_df['Type'] == 'GPU(Shared Constant) Tile Size = 34') | (lena_df['Type'] == 'GPU(Shared Constant) Tile Size = 36') | (lena_df['Type'] == 'GPU(Shared Constant) Tile Size = 38'))]["Run Time"].to_numpy()
L_tex = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& (lena_df['Type'] == 'GPU(Texture)')]["Run Time"].to_numpy()



#32
ax6.semilogy(n,L_CPU, label = "CPU")
ax6.semilogy(n,L_naive, label = 'Naive')
ax6.semilogy(n,L_gConst, label = "Global Constant")
ax6.semilogy(n,L_share, label = 'Shared')
ax6.semilogy(n,L_sConst, label = 'Shared Constant')
ax6.semilogy(n,L_tex, label = 'Texture')
ax6.set_title("Threads = "+str(i),fontsize = 13)
ax6.set_xlabel("Dimensions of Filter (NxN)",fontsize = 13)

ax6.legend(fontsize = 10, loc = 'best')
plt.subplots_adjust(wspace = 0.01,hspace = 0)
plt.show()

fig1.savefig('Harvard1080 Graph.png')

# %% [markdown]
# # Harvard2160

# %%
lena_df = pd.read_csv("Harvard2160.csv", sep = ';')

i = 8
L_CPU = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& (lena_df['Type'] == 'CPU')]["Run Time"].to_numpy()
L_naive = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& (lena_df['Type'] == 'GPU(Global)')]["Run Time"].to_numpy()
L_gConst = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& (lena_df['Type'] == 'GPU(Global Constant)')]["Run Time"].to_numpy()
L_share = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& ((lena_df['Type'] == 'GPU(Share) Tile Size = 10') | (lena_df['Type'] == 'GPU(Share) Tile Size = 12') | (lena_df['Type'] == 'GPU(Share) Tile Size = 14'))]["Run Time"].to_numpy()
L_sConst = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& ((lena_df['Type'] == 'GPU(Shared Constant) Tile Size = 10') | (lena_df['Type'] == 'GPU(Shared Constant) Tile Size = 12') | (lena_df['Type'] == 'GPU(Shared Constant) Tile Size = 14'))]["Run Time"].to_numpy()
L_tex = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& (lena_df['Type'] == 'GPU(Texture)')]["Run Time"].to_numpy()

n = [9,25,49]
fig2, (ax7,ax8,ax9) = plt.subplots(nrows = 1, ncols = 3,sharey='row', squeeze=True, figsize= (20,5))
fig2.suptitle("Run Times of Various Sized Filters Applied to a 2160x2160 Image",fontsize = 14)

#8
ax7.semilogy(n,L_CPU, label = "CPU")
ax7.semilogy(n,L_naive, label = 'Naive')
ax7.semilogy(n,L_gConst, label = "Global Constant")
ax7.semilogy(n,L_share, label = 'Shared')
ax7.semilogy(n,L_sConst, label = 'Shared Constant')
ax7.semilogy(n,L_tex, label = 'Texture')
ax7.set_title("Threads = "+str(i),fontsize = 13)
ax7.set_xlabel("Dimensions of Filter (NxN)",fontsize = 13)
ax7.set_ylabel("Run Time (ms)",fontsize = 13)

ax7.legend(fontsize = 10, loc = 'best')


i = 16
L_CPU = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& (lena_df['Type'] == 'CPU')]["Run Time"].to_numpy()
L_naive = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& (lena_df['Type'] == 'GPU(Global)')]["Run Time"].to_numpy()
L_gConst = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& (lena_df['Type'] == 'GPU(Global Constant)')]["Run Time"].to_numpy()
L_share = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& ((lena_df['Type'] == 'GPU(Share) Tile Size = 18') | (lena_df['Type'] == 'GPU(Share) Tile Size = 20') | (lena_df['Type'] == 'GPU(Share) Tile Size = 22'))]["Run Time"].to_numpy()
L_sConst = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& ((lena_df['Type'] == 'GPU(Shared Constant) Tile Size = 18') | (lena_df['Type'] == 'GPU(Shared Constant) Tile Size = 20') | (lena_df['Type'] == 'GPU(Shared Constant) Tile Size = 22'))]["Run Time"].to_numpy()
L_tex = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& (lena_df['Type'] == 'GPU(Texture)')]["Run Time"].to_numpy()



#16
ax8.semilogy(n,L_CPU, label = "CPU")
ax8.semilogy(n,L_naive, label = 'Naive')
ax8.semilogy(n,L_gConst, label = "Global Constant")
ax8.semilogy(n,L_share, label = 'Shared')
ax8.semilogy(n,L_sConst, label = 'Shared Constant')
ax8.semilogy(n,L_tex, label = 'Texture')
ax8.set_title("Threads = "+str(i),fontsize = 13)
ax8.set_xlabel("Dimensions of Filter (NxN)",fontsize = 13)

ax8.legend(fontsize = 10, loc = 'best')


i = 32
L_CPU = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& (lena_df['Type'] == 'CPU')]["Run Time"].to_numpy()
L_naive = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& (lena_df['Type'] == 'GPU(Global)')]["Run Time"].to_numpy()
L_gConst = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& (lena_df['Type'] == 'GPU(Global Constant)')]["Run Time"].to_numpy()
L_share = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& ((lena_df['Type'] == 'GPU(Share) Tile Size = 34') | (lena_df['Type'] == 'GPU(Share) Tile Size = 36') | (lena_df['Type'] == 'GPU(Share) Tile Size = 38'))]["Run Time"].to_numpy()
L_sConst = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& ((lena_df['Type'] == 'GPU(Shared Constant) Tile Size = 34') | (lena_df['Type'] == 'GPU(Shared Constant) Tile Size = 36') | (lena_df['Type'] == 'GPU(Shared Constant) Tile Size = 38'))]["Run Time"].to_numpy()
L_tex = lena_df[(lena_df['Thread'] == i) & (lena_df['Filter'] != 'Edge 3x3')& (lena_df['Type'] == 'GPU(Texture)')]["Run Time"].to_numpy()



#32
ax9.semilogy(n,L_CPU, label = "CPU")
ax9.semilogy(n,L_naive, label = 'Naive')
ax9.semilogy(n,L_gConst, label = "Global Constant")
ax9.semilogy(n,L_share, label = 'Shared')
ax9.semilogy(n,L_sConst, label = 'Shared Constant')
ax9.semilogy(n,L_tex, label = 'Texture')
ax9.set_title("Threads = "+str(i),fontsize = 13)
ax9.set_xlabel("Dimensions of Filter (NxN)",fontsize = 13)

ax9.legend(fontsize = 10, loc = 'best')
plt.subplots_adjust(wspace = 0.01,hspace = 0)
plt.show()

fig2.savefig('Harvard2160 Graph.png', aspect = 'auto')
